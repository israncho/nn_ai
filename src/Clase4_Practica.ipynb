# %%
##Clases basicas
import numpy as np

class Node:
    # Clase nodo
    def __call__(self,x):
        return self.forward(x)

    def __str__(self):
        return str(self.out)

class PreActivation(Node):
    # Pre-activación wx+b
    def __init__(self, input_size, output_size):
        self.w = np.random.uniform(0,1,input_size)
        self.b = np.random.uniform(0,1)

    def forward(self, x):
        return w * x + b

    def backward(self, error):
        self.grad_w = x * error  
        self.grad_b =  error 
            

class Sigmoid(Node):
    def __init__(self, node):
        self.preactivacion = node
    def forward(self,x):
        sigmoid = 1 / (1+np.exp(-self.preactivacion.forward(x)))
        return np.where(0.5 > sigmoid,0,1)
    def backward()
        


class BinaryCrossEntropy(Node):
    # Error de clasificación binario
    def __call__(self,x,y):
        self.prev, self.y = x, y
        self.out = -y*np.log(x.out) - (1-y)*np.log(1-x.out)
        return self

    def backward(self):

# %%
#Separacion de datos
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

x, y =

x_train, x_eval, y_train, y_eval = train_test_split(x, y, test_size=0.3)

plt.scatter(x_train[:,0], x_train[:,1], c=y_train)
plt.show()

# %%
##Linear regresion

from tqdm import tqdm

pre = PreActivation(2,1)
sig = Sigmoid(pre)
criterion = BinaryCrossEntropy(sig)

epochs = 100
lr = 0.1
for t in tqdm(range(epochs)):
    for x_i, y_i in zip(x_train, y_train):

        #pre.w -= a.grad_w *lr
        #pre.b -= a.grad_b *lr

# %%
#Evaluacion
from sklearn.metrics import classification_report

y_pred = [sig(pre(x_i)).argmax() for x_i in x_eval]
print(classification_report(y_pred, y_eval))

# %% [markdown]
# ###Ejemplo de salida
#
#
# ![image.png](data:image/png;base64,...)

# %%
##Perceptron
class Perceptron(Node):
    def forward(self, x):
        if ():
            return 1
        else:
            return 0

perc = Perceptron()
y_pred =
print(classification_report(y_pred, y_eval))

# %%
##Regresion lineal

class ?????(Node):

# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_samples=1000, n_features=2, n_informative=2)
x_train, x_eval, y_train, y_eval = train_test_split(x, y, test_size=0.3)

# %%
?????? = ???????
?????? = ??????()

epochs = 100
lr = 0.1
for t in tqdm(range(epochs)):
    for x_i, y_i in zip(x_train, y_train):
